# %% [markdown]
# Microsoft Windows [Version 10.0.19042.1526]
# (c) Microsoft Corporation. All rights reserved.
#
# C:\Users\Pepe Trujillo\Documents\folderfavorito\env\Scripts>activate
#
# (env) C:\Users\Pepe Trujillo\Documents\folderfavorito\env\Scripts>pip freeze
#
# (env) C:\Users\Pepe Trujillo\Documents\folderfavorito\env\Scripts>pip install python-dateutil
# Collecting python-dateutil
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting six>=1.5
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, python-dateutil
# Successfully installed python-dateutil-2.8.2 six-1.16.0
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\Pepe Trujillo\Documents\folderfavorito\env\Scripts\python.exe -m pip install --upgrade pip' command.
#
# (env) C:\Users\Pepe Trujillo\Documents\folderfavorito\env\Scripts>pip freeze
# python-dateutil==2.8.2
# six==1.16.0
#
# (env) C:\Users\Pepe Trujillo\Documents\folderfavorito\env\Scripts>deactivate
# C:\Users\Pepe Trujillo\Documents\folderfavorito\env\Scripts>
